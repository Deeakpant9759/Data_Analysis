# %%
import pandas as pd

# %%
coffee = pd.read_csv(r"complete-pandas-tutorial\warmup-data\coffee.csv")
coffee.index.name = 'ID'
bios = pd.read_csv(r"complete-pandas-tutorial\data\bios.csv")
bios.index = bios["athlete_id"]
bios = bios.drop("athlete_id",axis=1)
bios_new = bios.copy()

# %%
bios_new['Category'] = bios_new['height_cm'].apply(lambda x : 'Short' if x<165 else('Avarage' if x < 185 else 'Tall'))
bios_new

# %%
noc = pd.read_csv(r"complete-pandas-tutorial\data\noc_regions.csv")
noc

# %%
bios_noc = pd.merge(bios , noc , left_on='born_country',right_on='NOC',how='left',suffixes=('_left','_right'))
bios_noc.head()
# Out:
#                     name   born_date    born_city           born_region  \
# 0  Jean-François Blanchy  1886-12-12     Bordeaux               Gironde
# 1         Arnaud Boetsch  1969-04-01       Meulan              Yvelines
# 2           Jean Borotra  1898-08-13     Biarritz  Pyrénées-Atlantiques
# 3        Jacques Brugnon  1895-05-11  Paris VIIIe                 Paris
# 4           Albert Canet  1878-04-17   Wandsworth               England
#
#   born_country NOC_left  height_cm  weight_kg   died_date NOC_right  region  \
# 0          FRA   France        NaN        NaN  1960-10-02       FRA  France
# 1          FRA   France      183.0       76.0         NaN       FRA  France
# 2          FRA   France      183.0       76.0  1994-07-17       FRA  France
# 3          FRA   France      168.0       64.0  1978-03-20       FRA  France
# 4          GBR   France        NaN        NaN  1930-07-25       GBR      UK
#
#   notes
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN

# %%
not_things = bios_noc[bios_noc['NOC_right']!=bios_noc['born_country']]
not_things[['NOC_left','born_country','NOC_right']].head(10)

# %%
usa = bios_noc[bios_noc['born_country']=='USA'].copy()
gbr = bios_noc[bios_noc['born_country']=='GBR'].copy()
Ind = bios_noc[bios_noc['born_country']=='IND'].copy()

# %%
Ind.head()
# Out:
#                    name   born_date              born_city    born_region  \
# 80       George Caridia  1869-02-20     Kolkata (Calcutta)    West Bengal
# 101  Algernon Kingscote  1888-02-03  Bengaluru (Bangalore)      Karnataka
# 270         Nora Polley  1894-07-29                 Budaun  Uttar Pradesh
# 273         Zeeshan Ali  1970-01-01     Kolkata (Calcutta)    West Bengal
# 274      Anand Amritraj  1952-03-20       Chennai (Madras)     Tamil Nadu
#
#     born_country       NOC_left  height_cm  weight_kg   died_date NOC_right  \
# 80           IND  Great Britain        NaN        NaN  1937-04-21       IND
# 101          IND  Great Britain        NaN        NaN  1964-12-21       IND
# 270          IND          India        NaN        NaN  1988-01-01       IND
# 273          IND          India      180.0       64.0         NaN       IND
# 274          IND          India      185.0       77.0         NaN       IND
#
#     region notes
# 80   India   NaN
# 101  India   NaN
# ...
